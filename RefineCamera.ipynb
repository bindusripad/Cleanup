# %%
import pandas as pd

# %%
# read the contents of the csv file in a df variable
df = pd.read_csv('E:\DataScience\Camera.csv')

# %%
df.dtypes
# Out:
# Model                      object
# Release date               object
# Max resolution             object
# Low resolution             object
# Effective pixels           object
# Zoom wide (W)              object
# Zoom tele (T)              object
# Normal focus range         object
# Macro focus range          object
# Storage included           object
# Weight (inc. batteries)    object
# Dimensions                 object
# Price                      object
# dtype: object

# %%
# Remove duplicate rows
ids = df["Model"]

# %%
pd.concat(g for _, g in df.groupby("Model") if len(g) > 1)b
# Out:
#                  Model Release date Max resolution Low resolution  \
# 8  Canon PowerShot 350         1997            640              0
# 9  Canon PowerShot 350         1997            640              0
#
#   Effective pixels Zoom wide (W) Zoom tele (T) Normal focus range  \
# 8                0            42            42                 70
# 9                0            42            42                 70
#
#   Macro focus range Storage included Weight (inc. batteries) Dimensions Price
# 8                 3                2                     320         93   149
# 9                 3                2                     320         93   149

# %%
df[df.duplicated(keep=False)]
# Out:
#                  Model Release date Max resolution Low resolution  \
# 8  Canon PowerShot 350         1997            640              0
# 9  Canon PowerShot 350         1997            640              0
#
#   Effective pixels Zoom wide (W) Zoom tele (T) Normal focus range  \
# 8                0            42            42                 70
# 9                0            42            42                 70
#
#   Macro focus range Storage included Weight (inc. batteries) Dimensions Price
# 8                 3                2                     320         93   149
# 9                 3                2                     320         93   149

# %%
df.drop_duplicates(keep=False).head(10)
# Out:
#                      Model Release date Max resolution Low resolution  \
# 0                   STRING       DOUBLE         DOUBLE         DOUBLE
# 1         Agfa ePhoto 1280         1997           1024            640
# 2         Agfa ePhoto 1680         1998           1280            640
# 3         Agfa ePhoto CL18         2000            640              0
# 4         Agfa ePhoto CL30         1999           1152            640
# 5   Agfa ePhoto CL30 Clik!         1999           1152            640
# 6         Agfa ePhoto CL45         2001           1600            640
# 7         Agfa ePhoto CL50         1999           1280            640
# 10     Canon PowerShot A10         2001           1280           1024
# 11    Canon PowerShot A100         2002           1280           1024
#
#    Effective pixels Zoom wide (W) Zoom tele (T) Normal focus range  \
# 0            DOUBLE        DOUBLE        DOUBLE             DOUBLE
# 1                 0            38           114                 70
# 2                 1            38           114                 50
# 3                 0            45            45                  0
# 4                 0            35            35                  0
# 5                 0            43            43                 50
# 6                 1            51            51                 50
# 7                 1            34           102                  0
# 10                1            35           105                 76
# 11                1            39            39                 20
#
#    Macro focus range Storage included Weight (inc. batteries) Dimensions  \
# 0             DOUBLE           DOUBLE                  DOUBLE     DOUBLE
# 1                 40                4                     420         95
# 2                  0                4                     420        158
# 3                  0                2                       0          0
# 4                  0                4                       0          0
# 5                  0               40                     300        128
# 6                 20                8                     270        119
# 7                  0                8                       0          0
# 10                16                8                     375        110
# 11                 5                8                     225        110
#
#      Price
# 0   DOUBLE
# 1      179
# 2      179
# 3      179
# 4      269
# 5     1299
# 6      179
# 7        0
# 10     139
# 11     139

# %%
# Find rows with invalid year
df.loc[df['Release date'] < '1900']
# Out:
#                Model Release date Max resolution Low resolution  \
# 1029  Toshiba PDR-M3          123           1280            640
#
#      Effective pixels Zoom wide (W) Zoom tele (T) Normal focus range  \
# 1029                1            38           115                 90
#
#      Macro focus range Storage included Weight (inc. batteries) Dimensions  \
# 1029                25                4                     380        122
#
#      Price
# 1029    62

# %%
# Find rows with 0 or negative price
df.loc[df['Price'] <= '0']
# Out:
#                   Model Release date Max resolution Low resolution  \
# 7      Agfa ePhoto CL50         1999           1280            640
# 14  Canon PowerShot A30         2002           1280           1024
# 17  Canon PowerShot A40         2002           1600           1024
#
#    Effective pixels Zoom wide (W) Zoom tele (T) Normal focus range  \
# 7                 1            34           102                  0
# 14                1            35           105                 76
# 17                1            35           105                 76
#
#    Macro focus range Storage included Weight (inc. batteries) Dimensions Price
# 7                  0                8                       0          0     0
# 14                16                8                     350        110  -599
# 17                16                8                     350        110     0
